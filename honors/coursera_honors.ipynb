# %%
! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
import setup_google_colab
# please, uncomment the week you're working on
# setup_google_colab.setup_week1()  
# setup_google_colab.setup_week2()
# setup_google_colab.setup_week3()
# setup_google_colab.setup_week4()
#setup_google_colab.setup_project()
setup_google_colab.setup_honor()
# Out:
# --2019-12-18 07:25:10--  https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1991 (1.9K) [text/plain]
# Saving to: ‘setup_google_colab.py’
#
# setup_google_colab. 100%[===================>]   1.94K  --.-KB/s    in 0s
#
# 2019-12-18 07:25:11 (57.1 MB/s) - ‘setup_google_colab.py’ saved [1991/1991]

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install compress-pickle
# Out:
# Collecting compress-pickle
#   Downloading https://files.pythonhosted.org/packages/57/32/9728306b421e0ea786fb2c2a9a78159ac74dbe937b786285230578ab5913/compress_pickle-1.1.0-py3-none-any.whl
# Installing collected packages: compress-pickle
# Successfully installed compress-pickle-1.1.0

# %%
from compress_pickle import load,dump

# %%
fname = "/content/drive/My Drive/coursera/tokenizer"

# %%
tokenizer=load(fname, compression="lzma", set_default_extension=False)

# %%
# !mkdir -p "/content/drive/My Drive/coursera/data/cornell"

# %%
# !mkdir -p "/content/drive/My Drive/coursera/data/opensub"

# %%
# !cd "/content/drive/My Drive/coursera/data/opensub"

# %%
# !wget -O en.tar.gz http://opus.lingfil.uu.se/download.php?f=OpenSubtitles/en.tar.gz
# Out:
# --2019-12-18 03:39:50--  http://opus.lingfil.uu.se/download.php?f=OpenSubtitles/en.tar.gz
# Resolving opus.lingfil.uu.se (opus.lingfil.uu.se)... 130.238.78.148
# Connecting to opus.lingfil.uu.se (opus.lingfil.uu.se)|130.238.78.148|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://opus.nlpl.eu/download.php?f=OpenSubtitles/en.tar.gz [following]
# --2019-12-18 03:39:50--  http://opus.nlpl.eu/download.php?f=OpenSubtitles/en.tar.gz
# Resolving opus.nlpl.eu (opus.nlpl.eu)... 193.166.25.9
# Connecting to opus.nlpl.eu (opus.nlpl.eu)|193.166.25.9|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://object.pouta.csc.fi/OPUS-OpenSubtitles/v1/xml/en.zip [following]
# --2019-12-18 03:39:51--  https://object.pouta.csc.fi/OPUS-OpenSubtitles/v1/xml/en.zip
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18, 86.50.254.19
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148967861 (142M) [application/zip]
# Saving to: ‘en.tar.gz’
#
# en.tar.gz           100%[===================>] 142.07M  17.2MB/s    in 9.2s
#
# 2019-12-18 03:40:02 (15.4 MB/s) - ‘en.tar.gz’ saved [148967861/148967861]

# %%
# !unzip en.tar.gz
# Out:
# Archive:  en.tar.gz
#   inflating: INFO
#   inflating: README
#   inflating: LICENSE
#    creating: OpenSubtitles/
#    creating: OpenSubtitles/xml/
#    creating: OpenSubtitles/xml/en/
#    creating: OpenSubtitles/xml/en/History/
#    creating: OpenSubtitles/xml/en/History/1973/
#   inflating: OpenSubtitles/xml/en/History/1973/913_110311_150419_jesus_christ_superstar.info
#   inflating: OpenSubtitles/xml/en/History/1973/913_110311_150419_jesus_christ_superstar.xml
xml
#   inflating: OpenSubtitles/xml/en/Thriller/1993/1714_81086_107728_the_pelican_brief.info
#    creating: OpenSubtitles/xml/en/Thriller/1998/
#   inflating: OpenSubtitles/xml/en/Thriller/1998/134_19608_22231_pi.info
#   inflating: OpenSubtitles/xml/en/Thriller/1998/134_19608_22231_pi.xml
#    creating: OpenSubtitles/xml/en/Thriller/1999/
#   inflating: OpenSubtitles/xml/en/Thriller/1999/2082_133973_184043_eyes_wide_shut.info
#   inflating: OpenSubtitles/xml/en/Thriller/1999/2082_131381_180690_eyes_wide_shut.xml
#   inflating: OpenSubtitles/xml/en/Thriller/1999/2082_131381_180690_eyes_wide_shut.info
#   inflating: OpenSubtitles/xml/en/Thriller/1999/5845_77492_102383_double_jeopardy.xml
#   inflating: OpenSubtitles/xml/en/Thriller/1999/4617_133823_183836_arlington_road.info
#   inflating: OpenSubtitles/xml/en/Thriller/1999/4617_133823_183836_arlington_road.xml
#   inflating: OpenSubtitles/xml/en/Thriller/1999/5845_77492_102383_double_jeopardy.info
#   inflating: OpenSubtitles/xml/en/Thriller/1999/2082_133973_184043_eyes_wide_shut.xml
#    creating: OpenSubtitles/xml/en/1994/
#   inflating: OpenSubtitles/xml/en/1994/16176_198024_262100_venus_in_furs.xml
#   inflating: OpenSubtitles/xml/en/1994/16176_198024_262100_venus_in_furs.info

# %%
# !rm en.tar.gz

# %%
# !cd "/content/drive/My Drive/coursera/data/cornell"

# %%
# !wget https://github.com/Conchylicultor/DeepQA/raw/master/data/cornell/movie_conversations.txt --directory-prefix="/content/drive/My Drive/coursera/data/cornell"
# Out:
# --2019-12-15 05:16:15--  https://github.com/Conchylicultor/DeepQA/raw/master/data/cornell/movie_conversations.txt
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Conchylicultor/DeepQA/master/data/cornell/movie_conversations.txt [following]
# --2019-12-15 05:16:15--  https://raw.githubusercontent.com/Conchylicultor/DeepQA/master/data/cornell/movie_conversations.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6760930 (6.4M) [text/plain]
# Saving to: ‘/content/drive/My Drive/coursera/data/cornell/movie_conversations.txt’
#
# movie_conversations 100%[===================>]   6.45M  --.-KB/s    in 0.1s
#
# 2019-12-15 05:16:15 (45.7 MB/s) - ‘/content/drive/My Drive/coursera/data/cornell/movie_conversations.txt’ saved [6760930/6760930]

# %%
# !wget https://github.com/Conchylicultor/DeepQA/raw/master/data/cornell/movie_lines.txt --directory-prefix="/content/drive/My Drive/coursera/data/cornell"
# Out:
# --2019-12-16 07:12:47--  https://github.com/Conchylicultor/DeepQA/raw/master/data/cornell/movie_lines.txt
# Resolving github.com (github.com)... 13.229.188.59
# Connecting to github.com (github.com)|13.229.188.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Conchylicultor/DeepQA/master/data/cornell/movie_lines.txt [following]
# --2019-12-16 07:12:47--  https://raw.githubusercontent.com/Conchylicultor/DeepQA/master/data/cornell/movie_lines.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34641919 (33M) [text/plain]
# Saving to: ‘/content/drive/My Drive/coursera/data/cornell/movie_lines.txt.1’
#
# movie_lines.txt.1   100%[===================>]  33.04M   117MB/s    in 0.3s
#
# 2019-12-16 07:12:51 (117 MB/s) - ‘/content/drive/My Drive/coursera/data/cornell/movie_lines.txt.1’ saved [34641919/34641919]

# %%
import ast
import os
import random
import re
from time import time

import nltk
from tqdm import tqdm

"""
Load the cornell movie dialog corpus.

Available from here:
http://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html

"""

class CornellData:
    """

    """

    def __init__(self, dirName):
        """
        Args:
            dirName (string): directory where to load the corpus
        """
        self.lines = {}
        self.conversations = []

        MOVIE_LINES_FIELDS = ["lineID","characterID","movieID","character","text"]
        MOVIE_CONVERSATIONS_FIELDS = ["character1ID","character2ID","movieID","utteranceIDs"]

        self.lines = self.loadLines(os.path.join(dirName, "movie_lines.txt"), MOVIE_LINES_FIELDS)
        self.conversations = self.loadConversations(os.path.join(dirName, "movie_conversations.txt"), MOVIE_CONVERSATIONS_FIELDS)

        # TODO: Cleaner program (merge copy-paste) !!

    def loadLines(self, fileName, fields):
        """
        Args:
            fileName (str): file to load
            field (set<str>): fields to extract
        Return:
            dict<dict<str>>: the extracted fields for each line
        """
        lines = {}

        with open(fileName, 'r', encoding='iso-8859-1') as f:  # TODO: Solve Iso encoding pb !
            for line in f:
                values = line.split(" +++$+++ ")

                # Extract fields
                lineObj = {}
                for i, field in enumerate(fields):
                    lineObj[field] = values[i]

                lines[lineObj['lineID']] = lineObj

        return lines

    def loadConversations(self, fileName, fields):
        """
        Args:
            fileName (str): file to load
            field (set<str>): fields to extract
        Return:
            list<dict<str>>: the extracted fields for each line
        """
        conversations = []

        with open(fileName, 'r', encoding='iso-8859-1') as f:  # TODO: Solve Iso encoding pb !
            for line in f:
                values = line.split(" +++$+++ ")

                # Extract fields
                convObj = {}
                for i, field in enumerate(fields):
                    convObj[field] = values[i]

                # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
                lineIds = ast.literal_eval(convObj["utteranceIDs"])

                # Reassemble lines
                convObj["lines"] = []
                for lineId in lineIds:
                    convObj["lines"].append(self.lines[lineId])

                conversations.append(convObj)

        return conversations

    def getConversations(self):
        return self.conversations


# Based on code from https://github.com/AlJohri/OpenSubtitles
# by Al Johri <al.johri@gmail.com>

import xml.etree.ElementTree as ET
import datetime
import os
import sys
import json
import re
import pprint

from gzip import GzipFile

"""
Load the opensubtitles dialog corpus.
"""

class OpensubsData:
    """
    """

    def __init__(self, dirName):
        """
        Args:
            dirName (string): directory where to load the corpus
        """

        # Hack this to filter on subset of Opensubtitles
        # dirName = "%s/en/Action" % dirName

        print("Loading OpenSubtitles conversations in %s." % dirName)
        self.conversations = []
        self.tag_re = re.compile(r'(<!--.*?-->|<[^>]*>)')
        self.conversations = self.loadConversations(dirName)

    def loadConversations(self, dirName):
        """
        Args:
            dirName (str): folder to load
        Return:
            array(question, answer): the extracted QA pairs
        """
        conversations = []
        dirList = self.filesInDir(dirName)
        print(dirList)
        for filepath in tqdm(dirList):
              #print(filepath)
              #if filepath.endswith('gz'):
          try:
            doc = self.getXML(filepath)
            conversations.extend(self.genList(doc))
          except ValueError:
            tqdm.write("Skipping file %s with errors." % filepath)
          except:
            print("Unexpected error:")
                      #raise
        return conversations

    def getConversations(self):
        return self.conversations

    def genList(self, tree):
        root = tree.getroot()

        timeFormat = '%H:%M:%S'
        maxDelta = datetime.timedelta(seconds=1)

        startTime = datetime.datetime.min
        strbuf = ''
        sentList = []

        for child in root:
            for elem in child:
                if elem.tag == 'time':
                    elemID = elem.attrib['id']
                    elemVal = elem.attrib['value'][:-4]
                    if elemID[-1] == 'S':
                        startTime = datetime.datetime.strptime(elemVal, timeFormat)
                    else:
                        sentList.append((strbuf.strip(), startTime, datetime.datetime.strptime(elemVal, timeFormat)))
                        strbuf = ''
                else:
                    try:
                        strbuf = strbuf + " " + elem.text
                    except:
                        pass

        conversations = []
        for idx in range(0, len(sentList) - 1):
            cur = sentList[idx]
            nxt = sentList[idx + 1]
            if nxt[1] - cur[2] <= maxDelta and cur and nxt:
                tmp = {}
                tmp["lines"] = []
                tmp["lines"].append(self.getLine(cur[0]))
                tmp["lines"].append(self.getLine(nxt[0]))
                if self.filter(tmp):
                    conversations.append(tmp)

        return conversations

    def getLine(self, sentence):
        line = {}
        line["text"] = self.tag_re.sub('', sentence).replace('\\\'','\'').strip().lower()
        return line

    def filter(self, lines):
        # Use the followint to customize filtering of QA pairs
        #
        # startwords = ("what", "how", "when", "why", "where", "do", "did", "is", "are", "can", "could", "would", "will")
        # question = lines["lines"][0]["text"]
        # if not question.endswith('?'):
        #     return False
        # if not question.split(' ')[0] in startwords:
        #     return False
        #
        return True

    def getXML(self, filepath):
      fext = os.path.splitext(filepath)[1]
      if fext == '.gz':
          tmp = GzipFile(filename=filepath)
          return ET.parse(tmp)
      else:
          return ET.parse(filepath)

    def filesInDir(self, dirname):
        result = []
        for dirpath, dirs, files in os.walk(dirname):
            for filename in files:
                fname = os.path.join(dirpath, filename)
                result.append(fname)
        return result

def extractText(line, fast_preprocessing=True):
    if fast_preprocessing:
        GOOD_SYMBOLS_RE = re.compile('[^0-9a-z ]')
        REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;#+_]')
        REPLACE_SEVERAL_SPACES = re.compile('\s+')

        line = line.lower()
        line = REPLACE_BY_SPACE_RE.sub(' ', line)
        line = GOOD_SYMBOLS_RE.sub('', line)
        line = REPLACE_SEVERAL_SPACES.sub(' ', line)
        return line.strip()
    else:
        return nltk.word_tokenize(line)


def splitConversations(conversations, max_len=20, fast_preprocessing=True):
    data = []
    for i, conversation in enumerate(tqdm(conversations)):
        lines = conversation['lines']
        for i in range(len(lines) - 1):
            request = extractText(lines[i]['text'])
            reply = extractText(lines[i + 1]['text'])
            if 0 < len(request) <= max_len and 0 < len(reply) <= max_len:
                data += [(request, reply)]
    return data


def readCornellData(path, max_len=20, fast_preprocessing=True):
    dataset = CornellData(path)
    conversations = dataset.getConversations()
    return splitConversations(conversations, max_len=max_len, fast_preprocessing=fast_preprocessing)


def readOpensubsData(path, max_len=20, fast_preprocessing=True):
    dataset = OpensubsData(path)
    conversations = dataset.getConversations()
    return splitConversations(conversations, max_len=max_len, fast_preprocessing=fast_preprocessing)

# %%
data_opensub=readOpensubsData("OpenSubtitles")
# Out:
#   0%|          | 2/4634 [00:00<05:24, 14.29it/s]
# Loading OpenSubtitles conversations in OpenSubtitles.
 'OpenSubtitles/xml/en/Biography/2003/524_117208_159347_american_splendor.xml', 'OpenSubtitles/xml/en/Biography/2003/44_226933_300245_monster.xml', 'OpenSubtitles/xml/en/Biography/2003/2797_80670_107110_and_starring_pancho_villa_as_himself.xml', 'OpenSubtitles/xml/en/Biography/2003/44_64271_82800_monster.info', 'OpenSubtitles/xml/en/Biography/2003/524_117208_159347_american_splendor.info', 'OpenSubtitles/xml/en/Biography/2003/44_64271_82800_monster.xml', 'OpenSubtitles/xml/en/Biography/2003/524_125590_173030_american_splendor.info', 'OpenSubtitles/xml/en/Biography/2003/3451_85249_114079_ned_kelly.info', 'OpenSubtitles/xml/en/Biography/2003/4576_85571_114625_luther.info', 'OpenSubtitles/xml/en/Biography/2003/3451_85249_114079_ned_kelly.xml', 'OpenSubtitles/xml/en/Biography/2003/4576_85571_114625_luther.xml', 'OpenSubtitles/xml/en/Biography/2003/44_226933_300245_monster.info', 'OpenSubtitles/xml/en/Biography/2003/44_143196_195977_monster.info', 'OpenSubtitles/xml/en/Biography/1994/4395_152726_208200_ed_wood.info', 'OpenSubtitles/xml/en/Biography/1994/4395_152726_208200_ed_wood.xml', 'OpenSubtitles/xml/en/Biography/2005/5340_190099_252583_walk_t ...
# Unexpected error:
# Unexpected error:
#   0%|          | 12/4634 [00:00<03:52, 19.89it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   0%|          | 15/4634 [00:00<04:25, 17.41it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   1%|          | 25/4634 [00:01<03:50, 20.01it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   1%|          | 29/4634 [00:01<03:54, 19.61it/s]
# Unexpected error:
# Unexpected error:
#   1%|          | 35/4634 [00:01<03:41, 20.75it/s]
# Unexpected error:
# Unexpected error:
#   1%|          | 41/4634 [00:01<03:36, 21.19it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   1%|          | 56/4634 [00:02<02:32, 29.94it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   1%|▏         | 60/4634 [00:02<02:32, 29.91it/s]
# Unexpected error:
# Unexpected error:
#   2%|▏         | 73/4634 [00:02<02:14, 33.88it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   2%|▏         | 78/4634 [00:02<02:27, 30.85it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   2%|▏         | 91/4634 [00:03<02:07, 35.69it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   2%|▏         | 96/4634 [00:03<02:10, 34.69it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   2%|▏         | 101/4634 [00:03<02:47, 27.02it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   2%|▏         | 107/4634 [00:03<02:52, 26.31it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 117/4634 [00:04<02:46, 27.08it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 120/4634 [00:04<03:02, 24.71it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 128/4634 [00:04<02:55, 25.64it/s]
# Unexpected error:
# Unexpected error:
#   3%|▎         | 136/4634 [00:04<03:00, 24.91it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 145/4634 [00:05<02:42, 27.59it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 157/4634 [00:05<02:33, 29.20it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   3%|▎         | 161/4634 [00:05<02:59, 24.98it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   4%|▍         | 174/4634 [00:06<02:24, 30.96it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   4%|▍         | 185/4634 [00:06<03:18, 22.42it/s]
# Unexpected error:
#   4%|▍         | 191/4634 [00:06<02:43, 27.17it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   4%|▍         | 199/4634 [00:07<02:35, 28.53it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   4%|▍         | 203/4634 [00:07<03:08, 23.56it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   5%|▍         | 211/4634 [00:07<03:21, 21.99it/s]
# Unexpected error:
#   5%|▍         | 214/4634 [00:07<04:20, 16.97it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   5%|▍         | 224/4634 [00:08<03:24, 21.55it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   5%|▌         | 233/4634 [00:08<03:09, 23.25it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   5%|▌         | 236/4634 [00:09<04:28, 16.39it/s]
# Unexpected error:
#   5%|▌         | 245/4634 [00:09<03:50, 19.07it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   6%|▌         | 260/4634 [00:09<03:53, 18.76it/s]
# Unexpected error:
# Unexpected error:
#   6%|▌         | 269/4634 [00:10<03:43, 19.56it/s]
# Unexpected error:
#   6%|▌         | 276/4634 [00:10<03:47, 19.18it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   6%|▌         | 279/4634 [00:11<04:48, 15.11it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   6%|▋         | 294/4634 [00:11<03:14, 22.31it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   7%|▋         | 305/4634 [00:11<02:43, 26.43it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   7%|▋         | 312/4634 [00:12<03:28, 20.76it/s]
# Unexpected error:
# Unexpected error:
#   7%|▋         | 325/4634 [00:12<02:52, 24.93it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   7%|▋         | 338/4634 [00:13<02:39, 26.99it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   7%|▋         | 347/4634 [00:13<02:50, 25.17it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   8%|▊         | 358/4634 [00:13<02:41, 26.56it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   8%|▊         | 366/4634 [00:14<02:53, 24.56it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   8%|▊         | 384/4634 [00:14<02:15, 31.29it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   8%|▊         | 388/4634 [00:15<03:36, 19.57it/s]
# Unexpected error:
#   9%|▊         | 397/4634 [00:15<03:37, 19.51it/s]
# Unexpected error:
# Unexpected error:
#   9%|▊         | 405/4634 [00:15<03:48, 18.53it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   9%|▉         | 424/4634 [00:16<02:29, 28.07it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#   9%|▉         | 429/4634 [00:16<03:14, 21.66it/s]
# Unexpected error:
#   9%|▉         | 439/4634 [00:17<03:19, 21.02it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  10%|▉         | 448/4634 [00:17<03:23, 20.60it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  10%|▉         | 457/4634 [00:18<03:19, 20.90it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Skipping file OpenSubtitles/xml/en/Comedy/2003/529_124078_171007_how_to_lose_a_guy_in_10_days.xml with errors.
#  10%|█         | 465/4634 [00:18<03:51, 18.01it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  10%|█         | 482/4634 [00:19<02:51, 24.25it/s]
# Unexpected error:
# Unexpected error:
#  11%|█         | 496/4634 [00:19<02:48, 24.61it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  11%|█         | 504/4634 [00:20<03:12, 21.41it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  11%|█         | 515/4634 [00:20<02:57, 23.23it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  11%|█▏        | 526/4634 [00:21<02:53, 23.68it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  12%|█▏        | 541/4634 [00:21<02:36, 26.22it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  12%|█▏        | 548/4634 [00:22<03:05, 21.98it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  12%|█▏        | 563/4634 [00:22<02:40, 25.35it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  12%|█▏        | 567/4634 [00:22<02:22, 28.47it/s]
# Unexpected error:
# Unexpected error:
#  12%|█▏        | 575/4634 [00:23<03:00, 22.49it/s]
# Unexpected error:
# Unexpected error:
#  13%|█▎        | 582/4634 [00:23<03:53, 17.33it/s]
# Unexpected error:
#  13%|█▎        | 596/4634 [00:24<03:55, 17.13it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  13%|█▎        | 603/4634 [00:24<03:07, 21.51it/s]
# Unexpected error:
#  13%|█▎        | 619/4634 [00:24<02:46, 24.08it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  14%|█▎        | 633/4634 [00:25<02:30, 26.66it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  14%|█▍        | 640/4634 [00:25<02:08, 31.19it/s]
# Unexpected error:
#  14%|█▍        | 657/4634 [00:26<02:07, 31.27it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  14%|█▍        | 670/4634 [00:26<02:16, 29.06it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  15%|█▍        | 683/4634 [00:27<02:27, 26.83it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  15%|█▍        | 688/4634 [00:27<02:18, 28.57it/s]
# Unexpected error:
#  15%|█▌        | 697/4634 [00:27<03:11, 20.57it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  15%|█▌        | 701/4634 [00:28<04:08, 15.82it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  15%|█▌        | 710/4634 [00:28<03:12, 20.38it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  16%|█▌        | 720/4634 [00:28<03:07, 20.84it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  16%|█▌        | 726/4634 [00:29<02:30, 25.90it/s]
# Unexpected error:
#  16%|█▌        | 736/4634 [00:29<03:02, 21.35it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  16%|█▌        | 745/4634 [00:30<03:18, 19.57it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  16%|█▌        | 749/4634 [00:30<03:01, 21.42it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  16%|█▋        | 761/4634 [00:30<03:10, 20.32it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  17%|█▋        | 775/4634 [00:31<03:17, 19.57it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  17%|█▋        | 791/4634 [00:32<02:44, 23.39it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  17%|█▋        | 796/4634 [00:32<02:25, 26.46it/s]
# Unexpected error:
#  17%|█▋        | 805/4634 [00:32<03:14, 19.64it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  18%|█▊        | 814/4634 [00:33<03:29, 18.20it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  18%|█▊        | 818/4634 [00:33<03:01, 21.03it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  18%|█▊        | 837/4634 [00:34<02:28, 25.57it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Skipping file OpenSubtitles/xml/en/Comedy/2004/2480_226704_299940_little_black_book.xml with errors.
# Unexpected error:
#  18%|█▊        | 843/4634 [00:34<02:09, 29.31it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  18%|█▊        | 855/4634 [00:34<02:28, 25.39it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  19%|█▊        | 863/4634 [00:35<02:03, 30.64it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  19%|█▉        | 871/4634 [00:35<02:58, 21.04it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  19%|█▉        | 879/4634 [00:35<02:23, 26.18it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  19%|█▉        | 888/4634 [00:36<03:03, 20.41it/s]
# Unexpected error:
#  19%|█▉        | 891/4634 [00:36<02:59, 20.80it/s]
# Unexpected error:
#  20%|█▉        | 904/4634 [00:37<03:27, 18.00it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  20%|█▉        | 917/4634 [00:37<03:28, 17.79it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  20%|█▉        | 924/4634 [00:37<02:45, 22.41it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  20%|██        | 945/4634 [00:38<02:07, 28.82it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  21%|██        | 952/4634 [00:39<03:30, 17.48it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  21%|██        | 968/4634 [00:39<02:10, 28.09it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  21%|██        | 977/4634 [00:40<02:51, 21.33it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  21%|██        | 981/4634 [00:40<02:32, 23.94it/s]
# Unexpected error:
# Unexpected error:
#  21%|██▏       | 991/4634 [00:40<03:08, 19.36it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  21%|██▏       | 996/4634 [00:41<02:45, 21.95it/s]
# Unexpected error:
#  22%|██▏       | 1008/4634 [00:41<03:15, 18.51it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  22%|██▏       | 1024/4634 [00:42<02:29, 24.22it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  22%|██▏       | 1028/4634 [00:42<02:31, 23.87it/s]
# Unexpected error:
# Unexpected error:
#  22%|██▏       | 1038/4634 [00:43<03:03, 19.63it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  23%|██▎       | 1045/4634 [00:43<02:29, 23.98it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  23%|██▎       | 1059/4634 [00:43<02:34, 23.14it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  23%|██▎       | 1067/4634 [00:44<02:01, 29.38it/s]
# Unexpected error:
# Unexpected error:
#  23%|██▎       | 1076/4634 [00:44<02:52, 20.63it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
#  23%|██▎       | 1087/4634 [00:44<02:03, 28.77it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
#
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# 100%|█████████▉| 4611/4634 [02:24<00:00, 65.57it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# 100%|█████████▉| 4628/4634 [02:26<00:00, 24.84it/s]
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# Unexpected error:
# 100%|██████████| 4634/4634 [02:26<00:00, 31.68it/s]
#   1%|          | 9865/1648080 [00:00<00:16, 98642.10it/s]
# Unexpected error:
# 100%|██████████| 1648080/1648080 [00:18<00:00, 91425.63it/s]

# %%
data=readCornellData("/content/drive/My Drive/coursera/data/cornell")
# Out:
# 100%|██████████| 83097/83097 [00:02<00:00, 28597.65it/s]

# %%
data[:10][0][0]
# Out:
# 'there'

# %%
from tqdm import tqdm

# %%
a="How are You"
a.lower()
# Out:
# 'how are you'

# %%
def add_tokens(data):
  requests=[]
  replys=[]
  for i in tqdm(data):
    request=i[0]
    reply=i[1]
    request=request.rstrip().strip()
    reply=reply.rstrip().strip()
    request="<start> "+request+" <end>"
    reply="<start> "+reply+" <end>"
    request=request.lower()
    reply=reply.lower()
    requests.append(request)
    replys.append(reply)
  return requests, replys

# %%
requests,replys=add_tokens(data_opensub)
# Out:
# 100%|██████████| 166067/166067 [00:00<00:00, 1018035.01it/s]

# %%
print(requests[:10],replys[:10])
# Out:
# ['<start> congratulated <end>', '<start> does this stand me <end>', '<start> and what and <end>', '<start> how do you do that <end>', '<start> no he <end>', '<start> occupy <end>', '<start> i also <end>', '<start> here he has drunk <end>', '<start> what then <end>', '<start> i shot as a n meid <end>'] ['<start> it is again n year h <end>', '<start> and what and <end>', '<start> those leuke golf boy <end>', '<start> you go simply <end>', '<start> gives nothing <end>', '<start> aid necessary <end>', '<start> really where <end>', '<start> nou and <end>', '<start> pellet throws <end>', '<start> beautiful bordwerk <end>']

# %%
tf.__version__
# Out:
# '2.1.0-rc1'

# %%
embedding_dim = 200
units = 1024
vocab_size = len(tokenizer.word_index)+1
BATCH_SIZE=256

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
tokenizer=Tokenizer(filters='')

# %%
tokenizer.fit_on_texts(requests+replys)

# %%
requests_seq=tokenizer.texts_to_sequences(requests)

# %%
replys_seq=tokenizer.texts_to_sequences(replys)

# %%
len(tokenizer.word_index)
# Out:
# 25522

# %%
requests_seq[:10]
# Out:
# [[1, 21, 1350, 2],
#  [1, 2287, 56, 84, 2],
#  [1, 369, 2],
#  [1, 369, 2],
#  [1, 19, 24, 83, 2],
#  [1, 142, 56, 2],
#  [1, 108, 2],
#  [1, 12, 183, 390, 2],
#  [1, 5, 6, 12319, 2],
#  [1, 2360, 2]]

# %%
max_l=0
for i in range(len(requests)):
  max_l=max(max_l,len(requests[i].split()))
  max_l=max(max_l,len(replys[i].split()))

# %%
max_l
# Out:
# 11

# %%
requests[0]
# Out:
# '<start> congratulated <end>'

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
requests_seq=pad_sequences(requests_seq,maxlen=13,padding="post",truncating="post")

# %%
replys_seq=pad_sequences(replys_seq,maxlen=13,padding="post",truncating="post")

# %%
BUFFER_SIZE = len(requests_seq)

# %%
BATCH_SIZE = 256

# %%
steps_per_epoch = len(requests_seq)//BATCH_SIZE

# %%
embedding_dim = 200

# %%
units = 1024

# %%
vocab_size = len(tokenizer.word_index)+1

# %%
dataset = tf.data.Dataset.from_tensor_slices((requests_seq,replys_seq)).shuffle(BUFFER_SIZE)

# %%
dataset = dataset.batch(BATCH_SIZE, drop_remainder=False)

# %%
example_input_batch, example_target_batch = next(iter(dataset))

# %%
print(example_input_batch.shape,example_target_batch.shape)
# Out:
# (256, 13) (256, 13)

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_size, embedding_dim, units, BATCH_SIZE)

# %%
sample_hidden = encoder.initialize_hidden_state()

# %%
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)

# %%
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (256, 13, 1024)

# %%
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (256, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # hidden shape == (batch_size, hidden size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden size)
    # we are doing this to perform addition to calculate the score
    hidden_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(values) + self.W2(hidden_with_time_axis)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(100)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (256, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (256, 13, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_size, embedding_dim, units, BATCH_SIZE)

# %%
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

# %%
print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (256, 25523)

# %%
len(tokenizer.word_index)
# Out:
# 25522

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
import os

# %%
checkpoint_dir = "/content/drive/My Drive/coursera/training_checkpoints"
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
print(requests[:10])
print(replys[:10])
# Out:
# ['<start> congratulated <end>', '<start> does this stand me <end>', '<start> and what and <end>', '<start> how do you do that <end>', '<start> no he <end>', '<start> occupy <end>', '<start> i also <end>', '<start> here he has drunk <end>', '<start> what then <end>', '<start> i shot as a n meid <end>']
# ['<start> it is again n year h <end>', '<start> and what and <end>', '<start> those leuke golf boy <end>', '<start> you go simply <end>', '<start> gives nothing <end>', '<start> aid necessary <end>', '<start> really where <end>', '<start> nou and <end>', '<start> pellet throws <end>', '<start> beautiful bordwerk <end>']

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
import time

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  #if (epoch + 1) % 2 == 0:
  checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 1.1953
# Epoch 1 Batch 100 Loss 1.2362
# Epoch 1 Batch 200 Loss 1.2984
# Epoch 1 Batch 300 Loss 1.2269
# Epoch 1 Batch 400 Loss 1.2039
# Epoch 1 Batch 500 Loss 1.2141
# Epoch 1 Batch 600 Loss 1.2318
# Epoch 1 Loss 1.2462
# Time taken for 1 epoch 300.4957914352417 sec
#
# Epoch 2 Batch 0 Loss 1.1922
# Epoch 2 Batch 100 Loss 1.2214
# Epoch 2 Batch 200 Loss 1.2152
# Epoch 2 Batch 300 Loss 1.1571
# Epoch 2 Batch 400 Loss 1.2299
# Epoch 2 Batch 500 Loss 1.1806
# Epoch 2 Batch 600 Loss 1.1921
# Epoch 2 Loss 1.1846
# Time taken for 1 epoch 301.754207611084 sec
#
# Epoch 3 Batch 0 Loss 1.1459
# Epoch 3 Batch 100 Loss 1.1955
# Epoch 3 Batch 200 Loss 1.0729
# Epoch 3 Batch 300 Loss 1.1455
# Epoch 3 Batch 400 Loss 1.1763
# Epoch 3 Batch 500 Loss 1.1058
# Epoch 3 Batch 600 Loss 1.1238
# Epoch 3 Loss 1.1232
# Time taken for 1 epoch 302.4823913574219 sec
#
# Epoch 4 Batch 0 Loss 1.0502
# Epoch 4 Batch 100 Loss 1.0857
# Epoch 4 Batch 200 Loss 1.0102
# Epoch 4 Batch 300 Loss 1.1187
# Epoch 4 Batch 400 Loss 1.0638
# Epoch 4 Batch 500 Loss 1.0792
# Epoch 4 Batch 600 Loss 1.0392
# Epoch 4 Loss 1.0572
# Time taken for 1 epoch 303.45426964759827 sec
#
# Epoch 5 Batch 0 Loss 0.9491
# Epoch 5 Batch 100 Loss 0.9312
# Epoch 5 Batch 200 Loss 0.9893
# Epoch 5 Batch 300 Loss 0.9419
# Epoch 5 Batch 400 Loss 0.9803
# Epoch 5 Batch 500 Loss 1.0072
# Epoch 5 Batch 600 Loss 0.9702
# Epoch 5 Loss 0.9861
# Time taken for 1 epoch 302.82814168930054 sec
#
# Epoch 6 Batch 0 Loss 0.9626
# Epoch 6 Batch 100 Loss 0.8723
# Epoch 6 Batch 200 Loss 0.9024
# Epoch 6 Batch 300 Loss 0.9055
# Epoch 6 Batch 400 Loss 0.9092
# Epoch 6 Batch 500 Loss 0.9262
# Epoch 6 Batch 600 Loss 0.9188
# Epoch 6 Loss 0.9124
# Time taken for 1 epoch 302.66212129592896 sec
#
# Epoch 7 Batch 0 Loss 0.7804
# Epoch 7 Batch 100 Loss 0.8331
# Epoch 7 Batch 200 Loss 0.8400
# Epoch 7 Batch 300 Loss 0.8408
# Epoch 7 Batch 400 Loss 0.8577
# Epoch 7 Batch 500 Loss 0.8663
# Epoch 7 Batch 600 Loss 0.8472
# Epoch 7 Loss 0.8391
# Time taken for 1 epoch 303.03090500831604 sec
#
# Epoch 8 Batch 0 Loss 0.7411
# Epoch 8 Batch 100 Loss 0.7397
# Epoch 8 Batch 200 Loss 0.7471
# Epoch 8 Batch 300 Loss 0.7594
# Epoch 8 Batch 400 Loss 0.7662
# Epoch 8 Batch 500 Loss 0.7947
# Epoch 8 Batch 600 Loss 0.8252
# Epoch 8 Loss 0.7709
# Time taken for 1 epoch 303.2859892845154 sec
#
# Epoch 9 Batch 0 Loss 0.7016
# Epoch 9 Batch 100 Loss 0.6951
# Epoch 9 Batch 200 Loss 0.7108
# Epoch 9 Batch 300 Loss 0.7121
# Epoch 9 Batch 400 Loss 0.7333
# Epoch 9 Batch 500 Loss 0.7355
# Epoch 9 Batch 600 Loss 0.6897
# Epoch 9 Loss 0.7071
# Time taken for 1 epoch 303.2607400417328 sec
#
# Epoch 10 Batch 0 Loss 0.5971
# Epoch 10 Batch 100 Loss 0.6586
# Epoch 10 Batch 200 Loss 0.6312
# Epoch 10 Batch 300 Loss 0.6508
# Epoch 10 Batch 400 Loss 0.6578
# Epoch 10 Batch 500 Loss 0.6249
# Epoch 10 Batch 600 Loss 0.6202
# Epoch 10 Loss 0.6483
# Time taken for 1 epoch 303.9446268081665 sec

# %%
max_len=13

# %%
import string

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_len,max_len))
  sentence=sentence.lower()
  sentence=sentence.rstrip().strip()
  sentence=sentence.translate(str.maketrans('', '', string.punctuation))
  sentence = "<start> "+sentence+" <end>"

  inputs = [tokenizer.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_len,padding="post",truncating="post")
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)

  for t in range(max_len):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += tokenizer.index_word[predicted_id] + ' '
    print(result)
    if tokenizer.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def chat(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
tf.train.latest_checkpoint(checkpoint_dir)
# Out:
# '/content/drive/My Drive/coursera/training_checkpoints/ckpt-12'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.ticker as ticker

# %%
tokenizer.word_index["hello"]
# Out:
# 70

# %%
chat("what is your name")
# Out:
# ella
# ella of
# ella of frell
# ella of frell <end>
# Input: <start> what is your name <end>
# Predicted translation: ella of frell <end>

# %%
chat("how are you")
# Out:
# i
# i m
# i m fine
# i m fine <end>
# Input: <start> how are you <end>
# Predicted translation: i m fine <end>

# %%
chat("how was your trip")
# Out:
# it
# it s
# it s fine
# it s fine <end>
# Input: <start> how was your trip <end>
# Predicted translation: it s fine <end>

# %%
chat("lets play football")
# Out:
# okay
# okay <end>
# Input: <start> lets play football <end>
# Predicted translation: okay <end>

# %%
chat("who are you")
# Out:
# i
# i m
# i m raoul
# i m raoul <end>
# Input: <start> who are you <end>
# Predicted translation: i m raoul <end>

# %%
chat("where do you live")
# Out:
# couch
# couch <end>
# Input: <start> where do you live <end>
# Predicted translation: couch <end>

# %%
chat("where are you?")
# Out:
# i
# i m
# i m in
# i m in wichita
# i m in wichita <end>
# Input: <start> where are you <end>
# Predicted translation: i m in wichita <end>

# %%
checkpoint

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# '/content/drive/My Drive/coursera/training_checkpoints/ckpt-12'

# %%
# !ls "/content/drive/My Drive/coursera/training_checkpoints"
# Out:
# checkpoint		     ckpt-2.data-00001-of-00002
# ckpt-10.data-00000-of-00002  ckpt-2.index
# ckpt-10.data-00001-of-00002  ckpt-3.data-00000-of-00002
# ckpt-10.index		     ckpt-3.data-00001-of-00002
# ckpt-11.data-00000-of-00002  ckpt-3.index
# ckpt-11.data-00001-of-00002  ckpt-4.data-00000-of-00002
# ckpt-11.index		     ckpt-4.data-00001-of-00002
# ckpt-12.data-00000-of-00002  ckpt-4.index
# ckpt-12.data-00001-of-00002  ckpt-5.data-00000-of-00002
# ckpt-12.index		     ckpt-5.data-00001-of-00002
# ckpt-13.data-00000-of-00002  ckpt-5.index
# ckpt-13.data-00001-of-00002  ckpt-6.data-00000-of-00002
# ckpt-13.index		     ckpt-6.data-00001-of-00002
# ckpt-14.data-00000-of-00002  ckpt-6.index
# ckpt-14.data-00001-of-00002  ckpt-7.data-00000-of-00002
# ckpt-14.index		     ckpt-7.data-00001-of-00002
# ckpt-15.data-00000-of-00002  ckpt-7.index
# ckpt-15.data-00001-of-00002  ckpt-8.data-00000-of-00002
# ckpt-15.index		     ckpt-8.data-00001-of-00002
# ckpt-1.data-00000-of-00002   ckpt-8.index
# ckpt-1.data-00001-of-00002   ckpt-9.data-00000-of-00002
# ckpt-1.index		     ckpt-9.data-00001-of-00002
# ckpt-2.data-00000-of-00002   ckpt-9.index

# %%
# !pip install compress-pickle
# Out:
# Collecting compress-pickle
#   Downloading https://files.pythonhosted.org/packages/57/32/9728306b421e0ea786fb2c2a9a78159ac74dbe937b786285230578ab5913/compress_pickle-1.1.0-py3-none-any.whl
# Installing collected packages: compress-pickle
# Successfully installed compress-pickle-1.1.0

# %%
fname3 = "/content/drive/My Drive/coursera/tokenizer"

# %%
# !pip install compress-pickle
# Out:
# Requirement already satisfied: compress-pickle in /usr/local/lib/python3.6/dist-packages (1.1.0)

# %%
from compress_pickle import dump,load

# %%
dump(tokenizer, fname3, compression="lzma", set_default_extension=False)

# %%
tokenizer.word_index["hello"]
# Out:
# 69

# %%
tokenizer.word_index['5554202']
# Out:
# 4062
